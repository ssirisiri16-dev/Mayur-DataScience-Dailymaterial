# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa=df[df["species"]=="setosa"]

# %%
versicolor=df[df["species"]=="versicolor"]

# %%
virginica=df[df["species"]=="virginica"]

# %%
sample1=setosa["sepal_length"]

# %%
sample2=versicolor["sepal_length"]

# %%
sample3=virginica["sepal_length"]

# %%
means1=np.mean(sample1)

# %%
means2=np.mean(sample2)

# %%
means3=np.mean(sample3)

# %%
x_bar=np.sum(df["sepal_length"])/150

# %%
x_bar
# Out:
# np.float64(5.843333333333334)

# %%
ss1=(3*((means1-x_bar)**2))

# %%
ss1
# Out:
# np.float64(2.103381333333334)

# %%
ss2=(3*((means2-x_bar)**2))

# %%
ss2
# Out:
# np.float64(0.025761333333333088)

# %%
ss3=(3*((means3-x_bar)**2))

# %%
ss3
# Out:
# np.float64(1.6635853333333241)

# %%
ssb=ss1+ss2+ss3

# %%
ssb
# Out:
# np.float64(3.7927279999999914)

# %%
p1=np.sum((sample1-means1)**2)

# %%
p1
# Out:
# np.float64(6.088200000000001)

# %%
p2=np.sum((sample2-means2)**2)

# %%
p2
# Out:
# np.float64(13.055200000000001)

# %%
p3=np.sum((sample3-means3)**2)

# %%
p3
# Out:
# np.float64(19.812800000000006)

# %%
ssw=p1+p2+p3

# %%
ssw
# Out:
# np.float64(38.95620000000001)

# %%
df_between=49
df_within=100

# %%
MSB=ssb/df_between

# %%
MSW=ssw/df_within

# %%
f_statistics=MSB/MSW

# %%
f_statistics
# Out:
# np.float64(0.19869138223157742)

# %%
f_value=1.43

# %%
f_statistics>f_value
# Out:
# np.False_

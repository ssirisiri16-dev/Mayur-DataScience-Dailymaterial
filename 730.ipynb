# %%
a=5

# %%
a+=34//2*6-7&1

# %%
a
# Out:
# 6

# %%
a//=4//4|52&~

# %%
a
# Out:
# 1

# %%
a=2

# %%
a**=2*3|2

# %%
a
# Out:
# 7529536

# %%
a=2**2*3|2

# %%
a
# Out:
# 14

# %%
a=2

# %%
a**=2*3|2

# %%
a
# Out:
# 64

# %%
a=2
a**=23//3-5&1|3

# %%
a
# Out:
# 5

# %%
a=5
b=6

# %%
a*=b*3//4&1|12^1

# %%
a
# Out:
# 65

# %%
a,b=3,4

# %%
a
# Out:
# 3

# %%
b
# Out:
# 4

# %%
a=5
b=6

# %%
a,b=b,a

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
a=5
b=5

# %%
a is b
# Out:
# True

# %%
a=5
b=6

# %%
a is b
# Out:
# False

# %%
a=b=6

# %%
a
# Out:
# 6

# %%
b
# Out:
# 6

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 140724198028360

# %%
id(b)
# Out:
# 140724198028360

# %%
a=b=6

# %%
a is not b
# Out:
# False

# %%
a=6
b=7

# %%
a is not b
# Out:
# True

# %%
a=100
b=100

# %%
a is b
# Out:
# True

# %%
a=b=200

# %%
a is b
# Out:
# True

# %%
a=b=255

# %%
a is b
# Out:
# True

# %%
a=b=256

# %%
a is b
# Out:
# True

# %%
a=b=257

# %%
a is b
# Out:
# True

# %%
a=256
b=256

# %%
a is b
# Out:
# True

# %%
a=257
b=257

# %%
a is b
# Out:
# False

# %%
a=-5
b=-5

# %%
a is b
# Out:
# True

# %%
a=-6
b=-6

# %%
a is b
# Out:
# False

# %%
a=10000
b=10000

# %%
a is b
# Out:
# False

# %%
a=b=10000

# %%
a is b
# Out:
# True

# %%
lst=[1,2,3,4,5,6]

# %%
5 in lst
# Out:
# True

# %%
1000 in lst
# Out:
# False

# %%
1000 not in lst
# Out:
# True

# %%
5 not in lst
# Out:
# False

# %%
s={1,2,3,4,5,6}

# %%
6 in s
# Out:
# True

# %%
a=4**2//3*45&12^1

# %%
a
# Out:
# 1

# %%
b=12//3&1|-4

# %%
b
# Out:
# -4

# %%
a=5

# %%
type(a)
# Out:
# int

# %%
b=23.45

# %%
type(b)
# Out:
# float

# %%
c="abc"

# %%
type(c)
# Out:
# str

# %%
a=56

# %%
import sys

# %%
sys.getsizeof(a)
# Out:
# 28

# %%
a=4567890123456

# %%
sys.getsizeof(a)
# Out:
# 32

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("stroke-data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df=pd.read_csv("stroke-data.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df

# %%
df.drop(columns=["id"],inplace=True)

# %%
df

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df["gender"].value_counts()

# %%
df=df[df["gender"]!="Other"]

# %%
df["gender"].value_counts()

# %%
df["gender"]=df["gender"].apply(lambda x:1 if x=="Male" else 0)

# %%
df

# %%
df["age"]=df["age"].astype("int")

# %%
df.info()

# %%
df["hypertension"].unique()

# %%
df["heart_disease"].unique()

# %%
df["ever_married"].unique()

# %%
df["ever_married"]=df["ever_married"].apply(lambda x:1 if x=="Yes" else 0)

# %%
df.info()

# %%
df["work_type"].unique()

# %%
df["Residence_type"].unique()

# %%
df["Residence_type"]=df["Residence_type"].apply(lambda x:1 if x=="Urban" else 0)

# %%
df.info()

# %%
df["avg_glucose_level"]

# %%
df["bmi"].unique()

# %%
df["bmi"]=df["bmi"].fillna(np.mean(df["bmi"]))

# %%
df.isnull().sum()

# %%
df["smoking_status"].unique()

# %%
df["stroke"].unique()

# %%
df1=pd.read_csv(r"C:\Users\ttwrd\Downloads\Airbnb_Open_Data.csv")

# %%
df1

# %%
df1.isnull().sum()

# %%
df1.drop(columns=["id"],inplace=True)

# %%
df1

# %%
df1["NAME"]

# %%
df1.drop(columns=["NAME","host id"],inplace=True)

# %%
df1

# %%
df1["host_identity_verified"].value_counts()

# %%
df1=df1["host_identity_verified"].dropna()

# %%
df1.isnull().sum()

# %%
df1

# %%
df2=pd.read_csv(r"C:\Users\ttwrd\Downloads\Airbnb_Open_Data.csv")
# Out:
# C:\Users\ttwrd\AppData\Local\Temp\ipykernel_27432\1712768493.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv(r"C:\Users\ttwrd\Downloads\Airbnb_Open_Data.csv")

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df2=df2.dropna(subset=["host_identity_verified"])

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df2=df2.rename(columns={"host_identity_verified":"host_verified"})

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_verified    host name neighbourhood group  \
# 0       80014485718   unconfirmed     Madaline            Brooklyn
# ...

# %%
df2["host_verified"]=df2["host_verified"].apply(lambda x:1 if x=="verified" else 0)

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id  host_verified    host name neighbourhood group  \
# 0       80014485718              0     Madaline            Brooklyn
# ...

# %%
df2=df2.dropna(subset=["host name"])

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id  host_verified    host name neighbourhood group  \
# 0       80014485718              0     Madaline            Brooklyn
# ...

# %%
df2.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df2["cancellation_policy"].unique()
# Out:
# array(['strict', 'moderate', 'flexible', nan], dtype=object)

# %%
df2["cancellation_policy"].value_counts()
# Out:
# cancellation_policy
# moderate    34251
# strict      34016
# flexible    33970
# Name: count, dtype: int64

# %%
df2["cancellation_policy"]=df2["cancellation_policy"].fillna("moderate")
# Out:
# C:\Users\ttwrd\AppData\Local\Temp\ipykernel_27432\1474275435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["cancellation_policy"]=df2["cancellation_policy"].fillna("moderate")

# %%
a=-77
b=-34

# %%
a&b
# Out:
# -110

# %%
a|b
# Out:
# -1

# %%
23^12
# Out:
# 27

# %%
-23^12
# Out:
# -27

# %%
-56^-34
# Out:
# 22

# %%
-67 ^-37
# Out:
# 102

# %%
-56^-59
# Out:
# 13

# %%
-123^-89
# Out:
# 34

# %%
a=5
b=6

# %%
a=a^b
b=a^b
a=a^b

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
a=5

# %%
~a
# Out:
# -6

# %%
a=17

# %%
~a
# Out:
# -18

# %%
a=20

# %%
~a
# Out:
# -21

# %%
a=-12

# %%
~a
# Out:
# 11

# %%
a=-22

# %%
~a
# Out:
# 21

# %%
a=12&5|~6

# %%
a
# Out:
# -3

# %%
a=12^5&1|2

# %%
a
# Out:
# 15

# %%
a=5

# %%
~a
# Out:
# -6

# %%
a=12&11^2|1&~3

# %%
a
# Out:
# 10

# %%
5>>3
# Out:
# 0

# %%
7>>2
# Out:
# 1

# %%
10>>2
# Out:
# 2

# %%
40>>4
# Out:
# 2

# %%
100>>5
# Out:
# 3

# %%
-12>>2
# Out:
# -3

# %%
12<<2
# Out:
# 48

# %%
24<<3
# Out:
# 192

# %%
-12<<4
# Out:
# -192

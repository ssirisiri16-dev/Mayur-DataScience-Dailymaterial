# %%
-34>>3
# Out:
# -5

# %%
-216>>4
# Out:
# -14

# %%
-23|11^3&-1
# Out:
# -23

# %%
s="myaur"

# %%
s[2]
# Out:
# 'y'

# %%
s[4]
# Out:
# 'r'

# %%
s[-1]
# Out:
# 'r'

# %%
s[-2]
# Out:
# 'u'

# %%
s[1:4]
# Out:
# 'ayu'

# %%
s
# Out:
# 'mayur'

# %%
s[2:5]
# Out:
# 'yur'

# %%
s="mayur"

# %%
x=s.encode("UTF-8")

# %%
x
# Out:
# b'mayur'

# %%
s="abc"

# %%
p=s.encode("UTF-8")

# %%
p
# Out:
# b'abc'

# %%
type(p)
# Out:
# bytes

# %%
bin(p[0])
# Out:
# '0b1100001'

# %%
s1="pbc"

# %%
ss=s1.encode("UTF-8")

# %%
ss
# Out:
# b'pbc'

# %%
bin(ss[0])
# Out:
# '0b1110000'

# %%
bin(ss[1])
# Out:
# '0b1100010'

# %%
bin(ss[2])
# Out:
# '0b1100011'

# %%
s2="mayur"

# %%
ssr=s2.encode("UTF-8")

# %%
ssr
# Out:
# b'mayur'

# %%
bin(ssr[0])
# Out:
# '0b1101101'

# %%
bin(ssr[1])
# Out:
# '0b1100001'

# %%
bin(ssr[2])
# Out:
# '0b1111001'

# %%
bin(ssr[3])
# Out:
# '0b1110101'

# %%
bin(ssr[4])
# Out:
# '0b1110010'

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # heading1

# %% [markdown]
# ## heading2

# %% [markdown]
# ### heading3

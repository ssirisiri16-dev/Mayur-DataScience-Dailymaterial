# %%
import numpy as np

# %%
data=np.array([56,48,67,68,90,44,78,79,80,82,88,100,110])

# %%
m=np.mean(data)

# %%
m
# Out:
# np.float64(76.15384615384616)

# %%
sd=10/(np.sqrt(13))

# %%
len(data)
# Out:
# 13

# %%
sd
# Out:
# np.float64(2.773500981126146)

# %%
LL=(m-2*sd)

# %%
UL=(m+2*sd)

# %%
LL
# Out:
# np.float64(70.60684419159386)

# %%
UL
# Out:
# np.float64(81.70084811609846)
